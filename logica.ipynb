# %%
from logica import colab_logica
# Out:
# Could not import google.cloud.bigquery.
# Could not import google.cloud.auth.
# Could not import google.colab.widgets.

# %%
# %%logica Greet
# @Engine("duckdb");
# Greet(greeting: "Hello world!")
# Out:
# Query is stored at Greet_sql variable.
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre> ▚  Greet
# [..............................]  0.00% complete.</pre></div>
# The following table is stored at Greet variable.
#        greeting
# 0  Hello world!

# %%
# %%logica Beer
# @Engine("duckdb");
#
# @Ground(Beer);
# Beer(..r) :- `('https://github.com/plotly/datasets/blob/master/beers.csv?raw=true')`(..r);
#
# BeersInState(state) += 1 :- Beer(state:);
# BeersInCity(state, city) += 1 :- Beer(state:, city:);
#
# ArgMax5(x) = ArgMaxK(x, 5);
# BestCityForBeer(state:, city:,
#                 city_beers: BeersInCity(state, city),
#                 state_beers: BeersInState(state)) :-
#     state in ArgMax5{s -> BeersInState(s)},
#     city = ArgMax{c -> BeersInCity(state, c)};
# Out:
# Query is stored at Beer_sql variable.
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥ ▚  `('https://github.com/plotly/datasets/blob/master/beers.csv?raw=true')`
# ╨ ▚  Beer
# [..............................]  0.00% complete.</pre></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('logica', 'Beer', '@Engine("duckdb");\n\n@Ground(Beer);\nBeer(..r) :-\n    `(\'https://github.com/plotly/datasets/blob/master/beers.csv?raw=true\')`(..r);\n\nBeersInState(state) += 1 :- Beer(state:);\nBeersInCity(state, city) += 1 :- Beer(state:, city:);\n\nArgMax5(x) = ArgMaxK(x, 5);\nBestCityForBeer(state:, city:,\n                city_beers: BeersInCity(state, city),\n                state_beers: BeersInState(state)) :-\n    state in ArgMax5{s -> BeersInState(s)},\n    city = ArgMax{c -> BeersInCity(state, c)};\n')
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/colab_logica.py:158, in logica(line, cell)
#     156 @register_cell_magic
#     157 def logica(line, cell):
# --> 158   Logica(line, cell, run_query=True)
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/colab_logica.py:368, in Logica(line, cell, run_query)
#     365   raise Exception('Logica only supports BigQuery, PostgreSQL and SQLite '
#     366                   'for now.')
#     367 try:
# --> 368   result_map = concertina_lib.ExecuteLogicaProgram(
#     369     executions, sql_runner=sql_runner, sql_engine=engine,
#     370     display_mode=DISPLAY_MODE)
#     371 except infer.TypeErrorCaughtException as e:
#     372   e.ShowMessage()
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/common/concertina_lib.py:530, in ExecuteLogicaProgram(logica_executions, sql_runner, sql_engine, display_mode)
#     525     sql_runner(preamble, sql_engine, is_final=False)
#     527 concertina = Concertina(config, engine,
#     528                         iterations=iterations,
#     529                         display_mode=display_mode)
# --> 530 concertina.Run()
#     531 return engine.final_result
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/common/concertina_lib.py:235, in Concertina.Run(self)
#     233 def Run(self):
#     234   while self.actions_to_run:
# --> 235     self.RunOneAction()
#     236   self.UpdateDisplay(final=True)
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/common/concertina_lib.py:225, in Concertina.RunOneAction(self)
#     223 self.running_actions |= {one_action}
#     224 self.UpdateDisplay()
# --> 225 self.engine.Run(self.action[one_action].get('action', {}))
#     226 self.running_actions -= {one_action}
#     227 if one_action not in self.action_iterations_complete:
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/common/concertina_lib.py:42, in ConcertinaQueryEngine.Run(self, action)
#      40   print('Running predicate:', predicate, end='')
#      41 start = datetime.datetime.now()
# ---> 42 result = self.sql_runner(action['sql'], action['engine'],
#      43                          is_final=(predicate in self.final_predicates))
#      44 end = datetime.datetime.now()
#      45 self.completion_time[predicate] = int((end - start).total_seconds() * 1000)
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/colab_logica.py:245, in DuckdbRunner.__call__(self, sql, engine, is_final)
#     244 def  __call__(self, sql, engine, is_final):
# --> 245   return RunSQL(sql, engine, self.connection, is_final)
#
# File ~/Dropbox/research/phd2024/union/venv/lib/python3.10/site-packages/logica/colab_logica.py:192, in RunSQL(sql, engine, connection, is_final)
#     190 elif engine == 'duckdb':
#     191   if is_final:
# --> 192     df = connection.sql(sql).df()
#     193     for c in df.columns:
#     194       if df.dtypes[c] == 'float64':
#
# KeyboardInterrupt:

# %%
# %%logica Query
# @Engine("duckdb");
#
# Tall(..r) :- `('experiments/results/parquet_tall/df*.parquet')`(..r);
#
# @Limit(STables, 10);
# STables(..r) :- Tall(..r);
# Out:
# Query is stored at STables_sql variable.
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥ ▚  `('experiments/results/parquet_tall/df*.parquet')`
# ╨ ▚  STables
# [..............................]  0.00% complete.</pre></div>
# The following table is stored at STables variable.
#    index  fs  i  j   v
# 0      0  26  0  0   7
# 1      1  26  0  1  14
# 2      2  26  0  2   9
# 3      3  26  0  3   8
# 4      4  26  0  4   2
# 5      5  26  0  5  12
# 6      6  26  0  6   6
# 7      7  26  0  7  10
# 8      8  26  0  8   3
# 9      9  26  0  9  11
